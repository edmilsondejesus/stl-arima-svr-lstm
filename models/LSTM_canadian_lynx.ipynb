# %%
#!pip install pandas
#!pip install seaborn
#!pip install openpyxl

# %%
import pandas as pd
import numpy as np
import time
import csv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import model_from_json
from tensorflow import data
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
# #from google.colab import drive
#drive.mount('/content/drive')
file_data = 'lynx.csv'
path_name='../datasets/'
path_name_results='../results/'
file_result = 'Result_LSTM_canadian_lynx.csv'

# %%
dataset = pd.read_csv(f'{path_name}{file_data}', sep =',', encoding = 'latin1', decimal='.',usecols=[2])
dataset.columns = ['num_observations']

# %%
#checks if there are null variables
dataset.isna().sum()
# Out:
# num_observations    0
# dtype: int64

# %%
def salvar_resultado(nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration):
  #Script to write training cycle results
  data = [nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration]
  fields = ['Dataset','Best Params','n_time_steps','MSE', 'RMSE', 'MAE', 'MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "a",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(data)  
  print(fields)
  print(data)
    
#Script to create the results file
def criar_arquivo_resultado():
  fields = ['Dataset','Best Params','n_time_steps','MSE', 'RMSE', 'MAE','MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "w",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(fields)

# %%
# convert an array of values into a dataset matrix
def create_matrix_dataset(dataset, n_time_steps=1):
    dX, dY = [], []
    for i in range(len(dataset) - n_time_steps - 1):
        a = dataset[i:(i + n_time_steps)]
        dX.append(a)
        dY.append(dataset[i + n_time_steps])
    return np.array(dX), np.array(dY)

# %%
  
def save_model(model,n_time_steps):
  # serialize model to JSON
  model_json = model.to_json()
  with open(f'{path_name_results}model_{n_time_steps}.json', "w") as json_file:
    json_file.write(model_json)

  # serialize weights to HDF5
  model.save_weights(f'{path_name_results}model_{n_time_steps}.h5')
  print("Saved model to disk")

# %%
def gera_resultado(y_test, predict,nm_dataset, resultado, n_time_steps, Duracao):
 #Mean Squared Error (Mean Squared Difference Between Estimated Values and Actual Values) - MSE
 MSE = mean_squared_error(y_test, predict)    
 #Square Root of Mean Error - RMSE
 RMSE = np.sqrt(mean_squared_error(y_test, predict))    
 #Mean Absolute Distance or Mean Absolute Error - MAE
 MAE= median_absolute_error(y_pred=predict, y_true = y_test) 
  
 #Calculate the MAPE (Mean Absolute Percentage Error)
 MAPE = ((np.mean(np.abs(y_test -predict) / (y_test)))) * 100   
  
 sMAPE = round(
 	np.mean(
 		np.abs(predict - y_test) /
 		((np.abs(predict) + np.abs(y_test)))
 	)*100, 2
 ) 
 salvar_resultado(nm_dataset, resultado, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duracao)

# %%
def previsao_LSTM(nm_dataset, dataset, n_time_steps, l1, l2, l3, num_epochs, batch_size): 
    
    # Convert dataset to numpy array
    if isinstance(dataset, pd.DataFrame):
        dataset = dataset['num_observations'].values.astype('float32')
    else:
        dataset = np.array(dataset, dtype='float32')
    
    # Handle n_time_steps = 0
    if n_time_steps == 0:
        # For window zero, use only current value as feature
        nlinhas = int(len(dataset) * 0.80)
        test = dataset[nlinhas:len(dataset)]  
        train = dataset[0:nlinhas]
        
        # Check if we have enough data
        if len(train) <= 2 or len(test) <= 2:
            print(f"Skipping n_time_steps={n_time_steps}: train size={len(train)}, test size={len(test)}")
            return
        
        # Create dummy features
        X_train = np.ones((len(train) - 1, 1))
        X_test = np.ones((len(test) - 1, 1))
        
        Y_train = train[1:].reshape(-1, 1)
        Y_test = test[1:].reshape(-1, 1)
        
        # Check if arrays are not empty before reshaping
        if X_train.shape[0] == 0 or X_test.shape[0] == 0:
            print(f"Skipping n_time_steps={n_time_steps}: Empty arrays after creation")
            return
        
        # Reshape for LSTM [samples, time steps, features]
        X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
        
    else:
        # Original code for n_time_steps > 0
        nlinhas = int(len(dataset) * 0.80)
        test = dataset[nlinhas:len(dataset)]  
        train = dataset[0:nlinhas] 
        
        # Check if we have enough data
        if len(train) <= 2 or len(test) <= 2:
            print(f"Skipping n_time_steps={n_time_steps}: train size={len(train)}, test size={len(test)}")
            return
        
        X_train, Y_train = create_matrix_dataset(train, n_time_steps)
        X_test, Y_test = create_matrix_dataset(test, n_time_steps) 
        
        # Reshape for LSTM [samples, time steps, features]
        X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    
        # Check if arrays are not empty before reshaping
        if X_train.shape[0] == 0 or X_test.shape[0] == 0:
            print(f"Skipping n_time_steps={n_time_steps}: Empty arrays after creation")
            return
        
    # Apply MinMaxScaler
    scaler_X = MinMaxScaler(feature_range=(0, 1))
    scaler_y = MinMaxScaler(feature_range=(0, 1))
    
    # Reshape for scaling
    original_shape_X = X_train.shape
    X_train_flat = X_train.reshape(-1, 1)
    X_train_scaled = scaler_X.fit_transform(X_train_flat).reshape(original_shape_X)
    X_test_scaled = scaler_X.transform(X_test.reshape(-1, 1)).reshape(X_test.shape)
    
    Y_train_scaled = scaler_y.fit_transform(Y_train.reshape(-1, 1)).ravel()
    Y_test_original = Y_test.copy()
    
    
    # Build LSTM model 
    model = Sequential()
    
    if n_time_steps > 0:
        # Architecture for n_time_steps > 0
        model.add(LSTM(l1, input_shape=(n_time_steps, 1), return_sequences=True))
        model.add(LSTM(l2, return_sequences=True))
        model.add(LSTM(l3))
    else:
        # Architecture for n_time_steps == 0
        # Input shape is (1, 1) because we have 1 time step with 1 feature
        model.add(LSTM(l1, input_shape=(1, 1), return_sequences=True))
        model.add(LSTM(l2, return_sequences=False))  # return_sequences=False for last LSTM layer
        # No third LSTM layer for n_time_steps == 0 to maintain compatibility
    
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    # Stops training when loss stops improving
    early_stop = EarlyStopping(
        monitor='loss',           # monitors training loss
        patience=20,              # waits 20 epochs before stopping
        restore_best_weights=True, # reverts to the best model found
        verbose=0,                # prints message when stopping
        min_delta=0.0001          # minimum change to qualify as improvement
    )

    Hora_Inicio = time.time()
    
    resultado = f"LSTM ({l1},{l2},{l3}) n_time_steps={n_time_steps} epochs={num_epochs}"
    print(resultado)

    # Train model with early_stop
    model.fit(
        X_train_scaled, Y_train_scaled,
        epochs=num_epochs,        
        batch_size=batch_size,
        verbose=0,                
        shuffle=False,            
        callbacks=[early_stop]
    )
    
    # Predict
    predict_scaled = model.predict(X_test_scaled, batch_size=batch_size, verbose=0)
    
    # Inverse transform predictions
    predict = scaler_y.inverse_transform(predict_scaled)
    
    Hora_Fim = time.time()
    Duracao = Hora_Fim - Hora_Inicio
    
    # Calculate metrics with original scale values
    gera_resultado(Y_test_original.reshape(-1, 1), predict, 
                   nm_dataset, resultado, n_time_steps, Duracao)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#create file to results
criar_arquivo_resultado()

print('forecast for canadian lynx')
num_epochs = 200 # number of epochs for train
batch_size = 32


#l1, l2, l3 = 8, 18, 8    # 90.6444863489101, 86.26, 72.7875263690948

#for n_time_steps in range(1,25): #predict with 1 to 24 past values of medition 
#    previsao_LSTM('IBM', dataset, n_time_steps, l1, l2, l3,num_epochs, batch_size)


def random_model():
  for n_time_steps in [0, 3, 6, 9, 12, 15, 18, 21, 24]: #range(0,25): #predict with 0 to 24 past values of medition    
    for l1 in [20, 60, 100]: # chose layer 1 nodes - min 8 and max 100
        for l2 in [20, 60, 100]: # chose layer 2 nodes - min 8 and max 100
            for l3 in [20, 60, 100]: # chose layer 3 nodes - min 8 and max 100
                previsao_LSTM('c.lynx', dataset, n_time_steps, l1, l2, l3,num_epochs, batch_size)           
                
random_model()
# Out:
# forecast for canadian lynx
# LSTM (20,20,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,20) n_time_steps=0 epochs=200', 0, 1832963.5, 1353.8699, 1214.0, 303.39014530181885, 42.41, 5.8445045948028564]
# LSTM (20,20,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,60) n_time_steps=0 epochs=200', 0, 1828038.9, 1352.0499, 1214.0, 305.69777488708496, 42.37, 5.674156904220581]
# LSTM (20,20,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,100) n_time_steps=0 epochs=200', 0, 1822595.1, 1350.0353, 1214.0, 308.39548110961914, 42.31, 5.962535381317139]
# LSTM (20,60,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,20) n_time_steps=0 epochs=200', 0, 1800956.8, 1341.9973, 1235.7549, 321.58098220825195, 42.06, 5.54846978187561]
# LSTM (20,60,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,60) n_time_steps=0 epochs=200', 0, 1810464.9, 1345.5352, 1214.0, 315.1405096054077, 42.16, 5.253089904785156]
# LSTM (20,60,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,100) n_time_steps=0 epochs=200', 0, 1805150.1, 1343.5587, 1221.4664, 318.5413122177124, 42.09, 5.299750804901123]
# LSTM (20,100,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,20) n_time_steps=0 epochs=200', 0, 1797847.2, 1340.8383, 1247.3751, 324.06044006347656, 42.04, 5.398303031921387]
# LSTM (20,100,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,60) n_time_steps=0 epochs=200', 0, 1800638.5, 1341.8787, 1236.8982, 321.8249320983887, 42.06, 5.2671074867248535]
# LSTM (20,100,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,100) n_time_steps=0 epochs=200', 0, 1803814.5, 1343.0616, 1225.8699, 319.47176456451416, 42.08, 5.249890565872192]
# LSTM (60,20,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,20) n_time_steps=0 epochs=200', 0, 1800394.9, 1341.788, 1237.7805, 322.01316356658936, 42.06, 19.99370527267456]
# LSTM (60,20,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,60) n_time_steps=0 epochs=200', 0, 1806512.5, 1344.0657, 1217.1031, 317.6361322402954, 42.11, 4.983119010925293]
# LSTM (60,20,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,100) n_time_steps=0 epochs=200', 0, 1808242.1, 1344.709, 1214.0, 316.5213108062744, 42.13, 5.09657621383667]
# LSTM (60,60,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,20) n_time_steps=0 epochs=200', 0, 1807624.4, 1344.4792, 1214.0, 316.91529750823975, 42.13, 4.932588338851929]
# LSTM (60,60,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,60) n_time_steps=0 epochs=200', 0, 1805494.4, 1343.6869, 1220.3525, 318.31023693084717, 42.1, 5.18798565864563]
# LSTM (60,60,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,100) n_time_steps=0 epochs=200', 0, 1788285.9, 1337.2681, 1268.0, 333.8447570800781, 42.01, 5.111979007720947]
# LSTM (60,100,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,20) n_time_steps=0 epochs=200', 0, 1805525.5, 1343.6985, 1220.2526, 318.28954219818115, 42.1, 4.985749959945679]
# LSTM (60,100,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,60) n_time_steps=0 epochs=200', 0, 1802863.5, 1342.7075, 1229.084, 320.1575994491577, 42.07, 5.0394227504730225]
# LSTM (60,100,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,100) n_time_steps=0 epochs=200', 0, 1793166.8, 1339.0918, 1267.1935, 328.2890319824219, 42.01, 4.933486700057983]
# LSTM (100,20,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,20) n_time_steps=0 epochs=200', 0, 1790881.6, 1338.2383, 1268.0, 330.67848682403564, 42.0, 5.234041690826416]
# LSTM (100,20,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,60) n_time_steps=0 epochs=200', 0, 1795295.5, 1339.8864, 1257.7649, 326.2772560119629, 42.03, 5.7177793979644775]
# LSTM (100,20,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,100) n_time_steps=0 epochs=200', 0, 1814891.9, 1347.1792, 1214.0, 312.5396966934204, 42.22, 5.828830718994141]
# LSTM (100,60,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,20) n_time_steps=0 epochs=200', 0, 1789038.1, 1337.5493, 1268.0, 332.8728437423706, 42.01, 5.83936619758606]
# LSTM (100,60,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,60) n_time_steps=0 epochs=200', 0, 1787655.9, 1337.0325, 1268.0, 334.700870513916, 42.01, 5.73293399810791]
# LSTM (100,60,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,100) n_time_steps=0 epochs=200', 0, 1784077.1, 1335.6935, 1268.0, 340.7424211502075, 42.04, 5.674922466278076]
# LSTM (100,100,20) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,20) n_time_steps=0 epochs=200', 0, 1791822.9, 1338.5898, 1268.0, 329.65478897094727, 42.0, 5.657461404800415]
# LSTM (100,100,60) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,60) n_time_steps=0 epochs=200', 0, 1784375.5, 1335.8052, 1268.0, 340.12017250061035, 42.04, 5.572923421859741]
# LSTM (100,100,100) n_time_steps=0 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,100) n_time_steps=0 epochs=200', 0, 1782662.9, 1335.164, 1268.0, 344.3572759628296, 42.05, 6.101345539093018]
# LSTM (20,20,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,20) n_time_steps=3 epochs=200', 3, 635532.06, 797.20264, 331.20972, 111.99485063552856, 29.71, 11.618698596954346]
# LSTM (20,20,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,60) n_time_steps=3 epochs=200', 3, 604003.9, 777.1769, 295.92212, 108.77984762191772, 25.33, 13.275803089141846]
# LSTM (20,20,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,100) n_time_steps=3 epochs=200', 3, 585389.5, 765.1075, 259.86035, 98.13509583473206, 22.92, 11.834480047225952]
# LSTM (20,60,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,20) n_time_steps=3 epochs=200', 3, 603007.2, 776.5354, 319.95343, 101.35025978088379, 26.07, 11.254593849182129]
# LSTM (20,60,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,60) n_time_steps=3 epochs=200', 3, 586227.9, 765.6552, 279.21658, 98.20882081985474, 24.1, 10.977448225021362]
# LSTM (20,60,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,100) n_time_steps=3 epochs=200', 3, 609330.8, 780.59644, 207.77002, 119.95632648468018, 23.06, 10.667868852615356]
# LSTM (20,100,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,20) n_time_steps=3 epochs=200', 3, 600421.8, 774.8689, 250.1447, 112.66927719116211, 24.01, 10.618668556213379]
# LSTM (20,100,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,60) n_time_steps=3 epochs=200', 3, 582078.0, 762.94037, 269.31653, 98.41421246528625, 23.44, 11.037865400314331]
# LSTM (20,100,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,100) n_time_steps=3 epochs=200', 3, 586496.5, 765.83057, 244.59326, 104.32043075561523, 22.88, 11.126545906066895]
# LSTM (60,20,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,20) n_time_steps=3 epochs=200', 3, 659014.0, 811.79675, 231.07666, 82.21420645713806, 26.61, 11.173521280288696]
# LSTM (60,20,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,60) n_time_steps=3 epochs=200', 3, 589808.75, 767.99005, 288.4145, 94.33218240737915, 24.59, 13.293776273727417]
# LSTM (60,20,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,100) n_time_steps=3 epochs=200', 3, 576496.44, 759.2736, 258.8669, 91.15231037139893, 23.83, 11.332865715026855]
# LSTM (60,60,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,20) n_time_steps=3 epochs=200', 3, 679915.94, 824.5701, 240.05334, 105.31638860702515, 25.9, 11.586511850357056]
# LSTM (60,60,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,60) n_time_steps=3 epochs=200', 3, 612260.4, 782.4707, 234.84595, 115.72232246398926, 24.04, 12.253270149230957]
# LSTM (60,60,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,100) n_time_steps=3 epochs=200', 3, 606580.25, 778.83264, 194.26337, 121.33313417434692, 23.42, 12.61722731590271]
# LSTM (60,100,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,20) n_time_steps=3 epochs=200', 3, 656100.94, 810.00055, 222.8399, 139.6376132965088, 23.52, 12.21584701538086]
# LSTM (60,100,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,60) n_time_steps=3 epochs=200', 3, 632007.7, 794.98914, 202.60547, 133.90315771102905, 24.37, 11.952836036682129]
# LSTM (60,100,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,100) n_time_steps=3 epochs=200', 3, 610620.1, 781.4219, 188.64291, 122.01423645019531, 22.58, 12.219927310943604]
# LSTM (100,20,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,20) n_time_steps=3 epochs=200', 3, 614056.75, 783.61774, 210.16382, 80.98081350326538, 25.27, 11.573970556259155]
# LSTM (100,20,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,60) n_time_steps=3 epochs=200', 3, 619054.06, 786.79987, 201.70514, 108.58678817749023, 23.9, 12.975220918655396]
# LSTM (100,20,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,100) n_time_steps=3 epochs=200', 3, 601053.2, 775.2762, 193.21838, 104.7235369682312, 24.25, 11.681915044784546]
# LSTM (100,60,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,20) n_time_steps=3 epochs=200', 3, 645434.44, 803.38934, 236.4944, 110.1572036743164, 21.61, 10.73858118057251]
# LSTM (100,60,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,60) n_time_steps=3 epochs=200', 3, 623131.2, 789.3866, 201.89087, 125.17366409301758, 23.91, 10.537274599075317]
# LSTM (100,60,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,100) n_time_steps=3 epochs=200', 3, 645559.2, 803.467, 200.87952, 138.62004280090332, 22.67, 10.733584642410278]
# LSTM (100,100,20) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,20) n_time_steps=3 epochs=200', 3, 638971.56, 799.357, 186.06909, 125.28624534606934, 21.77, 10.903132200241089]
# LSTM (100,100,60) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,60) n_time_steps=3 epochs=200', 3, 678504.1, 823.7136, 177.23145, 140.64711332321167, 19.84, 10.698456048965454]
# LSTM (100,100,100) n_time_steps=3 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,100) n_time_steps=3 epochs=200', 3, 674589.0, 821.3337, 188.64441, 144.26798820495605, 23.09, 10.834701299667358]
# LSTM (20,20,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,20) n_time_steps=6 epochs=200', 6, 370017.8, 608.2909, 377.97586, 127.54532098770142, 31.39, 11.236624002456665]
# LSTM (20,20,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,60) n_time_steps=6 epochs=200', 6, 126395.164, 355.52097, 347.13403, 81.49325847625732, 23.36, 11.300272941589355]
# LSTM (20,20,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,100) n_time_steps=6 epochs=200', 6, 90777.14, 301.29245, 259.2362, 58.465033769607544, 25.42, 12.01754355430603]
# LSTM (20,60,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,20) n_time_steps=6 epochs=200', 6, 125643.14, 354.46176, 234.72177, 70.33100724220276, 22.69, 11.5357666015625]
# LSTM (20,60,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,60) n_time_steps=6 epochs=200', 6, 105665.2, 325.06186, 278.6324, 77.8127670288086, 22.92, 11.642230749130249]
# LSTM (20,60,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,100) n_time_steps=6 epochs=200', 6, 100420.71, 316.89227, 329.23523, 65.53251147270203, 22.06, 12.550292491912842]
# LSTM (20,100,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,20) n_time_steps=6 epochs=200', 6, 159933.84, 399.9173, 318.2915, 104.57179546356201, 26.91, 12.302589178085327]
# LSTM (20,100,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,60) n_time_steps=6 epochs=200', 6, 97249.516, 311.84854, 305.2423, 83.65467190742493, 23.13, 12.476084232330322]
# LSTM (20,100,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,100) n_time_steps=6 epochs=200', 6, 134401.69, 366.60837, 285.5879, 99.66157078742981, 23.72, 12.950238227844238]
# LSTM (60,20,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,20) n_time_steps=6 epochs=200', 6, 133063.81, 364.7791, 319.06223, 98.65089654922485, 25.41, 12.013447999954224]
# LSTM (60,20,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,60) n_time_steps=6 epochs=200', 6, 136049.56, 368.84897, 293.80438, 65.63165187835693, 23.9, 12.150983095169067]
# LSTM (60,20,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,100) n_time_steps=6 epochs=200', 6, 153751.31, 392.11136, 310.86475, 94.75571513175964, 27.37, 13.062419176101685]
# LSTM (60,60,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,20) n_time_steps=6 epochs=200', 6, 95472.61, 308.98642, 307.0571, 57.085031270980835, 20.42, 12.229839324951172]
# LSTM (60,60,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,60) n_time_steps=6 epochs=200', 6, 126303.2, 355.39163, 318.73334, 75.21390318870544, 23.34, 11.648129224777222]
# LSTM (60,60,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,100) n_time_steps=6 epochs=200', 6, 73601.07, 271.29517, 286.80276, 40.74050784111023, 20.25, 11.947046756744385]
# LSTM (60,100,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,20) n_time_steps=6 epochs=200', 6, 105118.195, 324.21936, 285.2749, 91.35475158691406, 25.03, 11.696165084838867]
# LSTM (60,100,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,60) n_time_steps=6 epochs=200', 6, 127111.55, 356.52707, 299.28693, 102.6548981666565, 24.63, 11.913201808929443]
# LSTM (60,100,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,100) n_time_steps=6 epochs=200', 6, 117643.33, 342.99173, 318.02582, 99.5143473148346, 24.6, 12.668525695800781]
# LSTM (100,20,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,20) n_time_steps=6 epochs=200', 6, 146860.56, 383.2239, 341.60657, 100.12065172195435, 27.17, 12.234198808670044]
# LSTM (100,20,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,60) n_time_steps=6 epochs=200', 6, 145279.56, 381.15555, 266.30365, 120.3648567199707, 25.23, 12.73168683052063]
# LSTM (100,20,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,100) n_time_steps=6 epochs=200', 6, 172612.44, 415.46652, 339.0311, 87.07059025764465, 26.77, 13.282172441482544]
# LSTM (100,60,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,20) n_time_steps=6 epochs=200', 6, 110586.445, 332.5454, 292.0053, 96.80384993553162, 25.97, 12.602825403213501]
# LSTM (100,60,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,60) n_time_steps=6 epochs=200', 6, 86048.39, 293.34006, 300.0993, 60.54146885871887, 21.86, 12.78768515586853]
# LSTM (100,60,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,100) n_time_steps=6 epochs=200', 6, 100015.55, 316.25235, 336.6518, 51.46758556365967, 21.55, 13.032251358032227]
# LSTM (100,100,20) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,20) n_time_steps=6 epochs=200', 6, 109828.8, 331.40427, 292.59183, 90.14174938201904, 25.58, 13.29466700553894]
# LSTM (100,100,60) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,60) n_time_steps=6 epochs=200', 6, 110325.41, 332.15268, 337.54263, 67.9527223110199, 23.31, 13.24861478805542]
# LSTM (100,100,100) n_time_steps=6 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,100) n_time_steps=6 epochs=200', 6, 119464.3, 345.63608, 315.96442, 107.92057514190674, 25.89, 13.336951732635498]
# LSTM (20,20,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,20) n_time_steps=9 epochs=200', 9, 420415.7, 648.3947, 359.33566, 91.69026017189026, 23.98, 11.899535417556763]
# LSTM (20,20,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,60) n_time_steps=9 epochs=200', 9, 523830.72, 723.76154, 546.2821, 100.15212297439575, 28.5, 12.199733972549438]
# LSTM (20,20,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,100) n_time_steps=9 epochs=200', 9, 499656.78, 706.8641, 553.4851, 95.73138356208801, 28.79, 13.440175533294678]
# LSTM (20,60,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,20) n_time_steps=9 epochs=200', 9, 273443.6, 522.91833, 367.7503, 72.77478575706482, 23.62, 12.273345947265625]
# LSTM (20,60,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,60) n_time_steps=9 epochs=200', 9, 317679.56, 563.6307, 398.28784, 78.85107398033142, 24.68, 13.163585186004639]
# LSTM (20,60,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,100) n_time_steps=9 epochs=200', 9, 188069.23, 433.6695, 380.2004, 56.964534521102905, 22.6, 13.41485047340393]
# LSTM (20,100,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,20) n_time_steps=9 epochs=200', 9, 251951.36, 501.94757, 405.3034, 68.50166916847229, 24.7, 31.168425798416138]
# LSTM (20,100,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,60) n_time_steps=9 epochs=200', 9, 330076.2, 574.5226, 453.48297, 80.55809736251831, 24.97, 18.131998777389526]
# LSTM (20,100,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,100) n_time_steps=9 epochs=200', 9, 178141.36, 422.06796, 389.25128, 52.6211142539978, 21.79, 19.41631293296814]
# LSTM (60,20,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,20) n_time_steps=9 epochs=200', 9, 402960.2, 634.79144, 473.1925, 87.73354887962341, 27.49, 14.9503333568573]
# LSTM (60,20,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,60) n_time_steps=9 epochs=200', 9, 254791.53, 504.7688, 418.35388, 67.86280870437622, 23.29, 15.714876413345337]
# LSTM (60,20,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,100) n_time_steps=9 epochs=200', 9, 254713.58, 504.69156, 383.7611, 67.92557835578918, 22.11, 16.887301445007324]
# LSTM (60,60,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,20) n_time_steps=9 epochs=200', 9, 201992.94, 449.43625, 342.128, 54.75330352783203, 22.47, 15.113253116607666]
# LSTM (60,60,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,60) n_time_steps=9 epochs=200', 9, 247215.36, 497.20755, 358.3391, 65.59574604034424, 22.44, 16.33299493789673]
# LSTM (60,60,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,100) n_time_steps=9 epochs=200', 9, 156474.05, 395.568, 285.75616, 33.659642934799194, 17.35, 17.14542555809021]
# LSTM (60,100,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,20) n_time_steps=9 epochs=200', 9, 203378.86, 450.97546, 440.682, 60.973602533340454, 23.06, 15.92707872390747]
# LSTM (60,100,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,60) n_time_steps=9 epochs=200', 9, 202738.77, 450.26523, 270.56494, 36.843475699424744, 16.16, 17.64770007133484]
# LSTM (60,100,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,100,100) n_time_steps=9 epochs=200', 9, 203321.53, 450.9119, 301.9356, 37.41794228553772, 16.69, 17.529590606689453]
# LSTM (100,20,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,20) n_time_steps=9 epochs=200', 9, 325255.44, 570.3117, 430.6433, 79.69561219215393, 26.49, 13.81223750114441]
# LSTM (100,20,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,60) n_time_steps=9 epochs=200', 9, 277750.47, 527.0204, 426.78314, 74.42352771759033, 25.91, 14.638216257095337]
# LSTM (100,20,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,20,100) n_time_steps=9 epochs=200', 9, 335415.72, 579.1509, 480.3705, 80.23924231529236, 25.73, 15.403371334075928]
# LSTM (100,60,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,20) n_time_steps=9 epochs=200', 9, 302680.22, 550.1638, 500.8484, 75.85802674293518, 25.3, 14.847804307937622]
# LSTM (100,60,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,60) n_time_steps=9 epochs=200', 9, 210570.67, 458.8798, 290.2445, 50.40997266769409, 21.23, 15.647600650787354]
# LSTM (100,60,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,60,100) n_time_steps=9 epochs=200', 9, 273575.38, 523.0443, 321.20605, 42.71164536476135, 18.55, 16.635197639465332]
# LSTM (100,100,20) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,20) n_time_steps=9 epochs=200', 9, 116332.234, 341.0751, 247.11981, 47.2060352563858, 17.96, 15.569278955459595]
# LSTM (100,100,60) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,60) n_time_steps=9 epochs=200', 9, 232908.16, 482.6056, 276.89322, 42.517855763435364, 18.52, 16.016072273254395]
# LSTM (100,100,100) n_time_steps=9 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (100,100,100) n_time_steps=9 epochs=200', 9, 249975.78, 499.97577, 263.97372, 28.080055117607117, 14.08, 16.31466770172119]
# LSTM (20,20,20) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,20) n_time_steps=12 epochs=200', 12, 2064584.2, 1436.8661, 755.3184, 71.11649513244629, 56.51, 13.238877773284912]
# LSTM (20,20,60) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,60) n_time_steps=12 epochs=200', 12, 1181146.0, 1086.8054, 474.82138, 57.84603953361511, 35.84, 13.763236045837402]
# LSTM (20,20,100) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,20,100) n_time_steps=12 epochs=200', 12, 1061946.8, 1030.508, 536.7363, 56.82050585746765, 39.24, 16.477011919021606]
# LSTM (20,60,20) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,20) n_time_steps=12 epochs=200', 12, 2291279.5, 1513.6973, 746.5621, 71.78300619125366, 59.4, 13.985379695892334]
# LSTM (20,60,60) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,60) n_time_steps=12 epochs=200', 12, 1990771.6, 1410.947, 827.8859, 70.99946141242981, 58.45, 15.786866664886475]
# LSTM (20,60,100) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,60,100) n_time_steps=12 epochs=200', 12, 1936692.4, 1391.651, 365.7864, 43.65894794464111, 33.05, 15.849767684936523]
# LSTM (20,100,20) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,20) n_time_steps=12 epochs=200', 12, 1913754.0, 1383.385, 760.0227, 73.89730215072632, 63.17, 15.314687728881836]
# LSTM (20,100,60) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,60) n_time_steps=12 epochs=200', 12, 1549428.6, 1244.7605, 572.7565, 53.92413139343262, 39.7, 15.797456502914429]
# LSTM (20,100,100) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (20,100,100) n_time_steps=12 epochs=200', 12, 2123101.5, 1457.0867, 408.88342, 39.931026101112366, 29.47, 17.157196521759033]
# LSTM (60,20,20) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,20) n_time_steps=12 epochs=200', 12, 2401809.0, 1549.7771, 786.9566, 76.09463930130005, 65.43, 14.712750673294067]
# LSTM (60,20,60) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,60) n_time_steps=12 epochs=200', 12, 1991767.4, 1411.2999, 608.84485, 67.16328859329224, 53.9, 15.133177280426025]
# LSTM (60,20,100) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,20,100) n_time_steps=12 epochs=200', 12, 2362724.8, 1537.1157, 500.3527, 56.122082471847534, 44.67, 16.316658973693848]
# LSTM (60,60,20) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,20) n_time_steps=12 epochs=200', 12, 706849.7, 840.7435, 637.281, 50.2641499042511, 36.07, 14.13459825515747]
# LSTM (60,60,60) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,60) n_time_steps=12 epochs=200', 12, 1026624.9, 1013.225, 506.08484, 45.62932848930359, 32.03, 14.318382740020752]
# LSTM (60,60,100) n_time_steps=12 epochs=200
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', 'LSTM (60,60,100) n_time_steps=12 epochs=200', 12, 737675.8, 858.88055, 310.14737, 33.295416831970215, 20.57, 15.0210542678833]
# LSTM (60,100,20) n_time_steps=12 epochs=200
