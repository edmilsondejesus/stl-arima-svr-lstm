# %%
#!pip install seaborn
#!pip install openpyxl
#!pip install sklearn

# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sbs
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from matplotlib import pyplot
import time
import csv
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

# %%
file_data = 'lynx.csv'
path_name='../datasets/'
path_name_results='../results/'
file_result = 'Result_SVR_canadian_lynx.csv'

# %%
dataset = pd.read_csv(f'{path_name}{file_data}', sep =',', encoding = 'latin1', decimal='.')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  114 non-null    int64
#  1   time      114 non-null    int64
#  2   value     114 non-null    int64
# dtypes: int64(3)
# memory usage: 2.8 KB

# %%
#verifica se existe variáveis nulas 
dataset.isna().sum()
# Out:
# rownames    0
# time        0
# value       0
# dtype: int64

# %%
def salvar_resultado(nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration):
  #Script to write training cycle results
  data = [nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration]
  fields = ['Dataset','Best Params','n_time_steps','MSE','RMSE','MAE','MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "a",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(data)  
  print(fields)
  print(data)
    
#Script to create the results file
def criar_arquivo_resultado():
  fields = ['Dataset','Best Params','n_time_steps','MSE','RMSE','MAE','MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "w",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(fields)

# %%
def previsao_SVR(nm_dataset, dataset, n_time_steps):
    
    # Handle n_time_steps = 0 (no lag features)
    if n_time_steps == 0:
        # Create a constant feature for the model to work
        df = pd.DataFrame()
        df['value'] = dataset['value']
        df['constant'] = 1  # dummy feature
        df.dropna(inplace=True)
        
        # Split dataset into train (80%) and test (20%)
        nlinhas = int(np.round(df.shape[0] * 0.80))
        
        max_size_train_split = int(np.round(nlinhas / 5))
        max_size_test_split = int(np.round((df.shape[0] - nlinhas) / 5))
        size_split = 5
        
        # Prepare training data
        X_train = df.iloc[0:nlinhas, 1:2]  # constant column only
        y_train = df.iloc[0:nlinhas, 0].values
        
        # Prepare test data
        X_test = df.iloc[nlinhas:dataset.shape[0], 1:2]
        y_test = df.iloc[nlinhas:dataset.shape[0], 0].values
        
    else:
        # Original code for n_time_steps > 0
        # Dataframe treatment
        df = pd.DataFrame()
        df['value'] = dataset['value']
        
        # Time series transform - create lag features
        for n_step in range(1, n_time_steps + 1, 1):
            df['vl-' + str(n_step)] = dataset['value'].shift(n_step)
        
        df.dropna(inplace=True)
        
        # Split dataset into train (80%) and test (20%)
        nlinhas = int(np.round(df.shape[0] * 0.80))
        
        max_size_train_split = int(np.round(nlinhas / 5))
        max_size_test_split = int(np.round((df.shape[0] - nlinhas) / 5))
        size_split = 5
        
        # Prepare training data
        X_train = df.iloc[0:nlinhas, 1:1 + n_time_steps]
        y_train = df.iloc[0:nlinhas, 0].values
        
        # Prepare test data
        X_test = df.iloc[nlinhas:dataset.shape[0], 1:1 + n_time_steps]
        y_test = df.iloc[nlinhas:dataset.shape[0], 0].values
    
    # Apply StandardScale
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()
    
    # Scale features
    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    
    # Scale target
    y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).ravel()
    
    # Store training execution start time
    Hora_Inicio = time.time()
    
    # Time series cross-validation
    ts_cv = TimeSeriesSplit(
        n_splits=size_split,
        max_train_size=max_size_train_split,
        gap=2,
        test_size=max_size_test_split,
    )
    
    # Hyperparameters for SVR
    C = [12550, 125550, 1255555]
    gamma = [0.00001, 0.000001, 0.0000001, 0.00000001]
    epsilon = [0.1, 0.01, 0.001, 0.0001]
    
    hyper_params = [{'kernel': ['rbf'], 'C': C, 'gamma': gamma, 'epsilon': epsilon}]
    
    # Create SVR model
    modelo = SVR(max_iter=3000)
    
    # Grid search with cross-validation using scaled data
    grid = GridSearchCV(
        modelo,
        param_grid=hyper_params,
        verbose=20,
        n_jobs=-4,
        cv=ts_cv,
        scoring='neg_mean_absolute_percentage_error'
    )
    
    # Train on scaled data
    grid.fit(X_train_scaled, y_train_scaled)
    
    resultado = str(grid.best_params_)
    
    # Predict on scaled test data
    predict_scaled = grid.predict(X_test_scaled)
    
    # Inverse transform predictions to original scale
    predict = scaler_y.inverse_transform(predict_scaled.reshape(-1, 1)).ravel()
    
    # Store training execution end time
    Hora_Fim = time.time()
    
    # Calculate training execution duration
    Duracao = Hora_Fim - Hora_Inicio
    
    # Calculate metrics with original scale values
    # Mean Squared Error
    MSE = mean_squared_error(y_test, predict)
    
    # Root Mean Squared Error
    RMSE = np.sqrt(mean_squared_error(y_test, predict))
    
    # Mean Absolute Error
    MAE = median_absolute_error(y_pred=predict, y_true=y_test)
    
    # Mean Absolute Percentage Error (with protection against division by zero)
    MAPE = ((np.mean(np.abs(y_test - predict) / (y_test + 1e-10)))) * 100
    
    # Symmetric Mean Absolute Percentage Error (with protection against division by zero)
    sMAPE = round(
        np.mean(
            np.abs(predict - y_test) /
            ((np.abs(predict) + np.abs(y_test)) + 1e-10)
        ) * 100, 2
    )
    
    # Save results
    salvar_resultado(nm_dataset, resultado, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duracao)

# %%
#create file to results
criar_arquivo_resultado()

print('forecast for new sunspot number')
for n_time_steps in range(0,25): #predict with 0 to 25 past values of medition
    grid = previsao_SVR('c.lynx', dataset, n_time_steps)
# Out:
# forecast for new sunspot number
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-05, 'kernel': 'rbf'}", 0, 2751586.3402701495, 1658.7906258084984, 805.1275539643952, 153.8099131470031, 47.29, 3.60174560546875]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 125550, 'epsilon': 0.1, 'gamma': 1e-06, 'kernel': 'rbf'}", 1, 1111000.6677106898, 1054.0401641828882, 617.8490207827884, 100.98571616036422, 30.49, 0.11167693138122559]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-05, 'kernel': 'rbf'}", 2, 773734.3388828897, 879.6217021441033, 393.9593878376174, 153.78061385037307, 27.41, 0.10164761543273926]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-06, 'kernel': 'rbf'}", 3, 726960.0349085802, 852.6195135631017, 356.2049179377583, 111.89994981181606, 25.32, 0.10705304145812988]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 4, 666938.4625145787, 816.6630042524142, 387.2193930350092, 184.79042521871833, 30.02, 0.11445498466491699]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.0001, 'gamma': 1e-07, 'kernel': 'rbf'}", 5, 572646.4037002992, 756.7340376250424, 483.6570314774342, 117.72677622688508, 25.13, 0.11501526832580566]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.001, 'gamma': 1e-08, 'kernel': 'rbf'}", 6, 2613572.2593008727, 1616.6546505982262, 682.1021859602834, 145.54344375996897, 45.41, 0.11438417434692383]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-05, 'kernel': 'rbf'}", 7, 722638.3932610301, 850.0814039026087, 456.3686365601866, 135.98420955474134, 27.85, 0.11895442008972168]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.0001, 'gamma': 1e-07, 'kernel': 'rbf'}", 8, 617076.7589022398, 785.5423342521012, 480.0581029770128, 114.75777433882823, 32.66, 0.12159442901611328]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-05, 'kernel': 'rbf'}", 9, 794324.3034601457, 891.2487326555622, 417.74424924841855, 200.36122273785276, 33.77, 0.14171385765075684]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-08, 'kernel': 'rbf'}", 10, 2245707.260404501, 1498.5684036454595, 567.1562320732309, 144.3478400085977, 43.67, 0.10106873512268066]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.0001, 'gamma': 1e-05, 'kernel': 'rbf'}", 11, 603128.2958489135, 776.6133502901644, 416.00742960221305, 136.26370732368096, 30.32, 0.10511636734008789]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.0001, 'gamma': 1e-07, 'kernel': 'rbf'}", 12, 655930.8809389815, 809.8955987897339, 582.2276060575246, 144.6987693523164, 26.52, 0.10324740409851074]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 125550, 'epsilon': 0.0001, 'gamma': 1e-06, 'kernel': 'rbf'}", 13, 560756.5037928506, 748.8367671214139, 485.9912053927235, 141.1354275625713, 31.1, 0.10824155807495117]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.0001, 'gamma': 1e-08, 'kernel': 'rbf'}", 14, 858752.0861904996, 926.6887752587163, 576.2353462620101, 129.86437401175442, 33.69, 0.11646413803100586]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 15, 1919990.5610122862, 1385.6372400496048, 584.3199990831821, 142.9556006402915, 40.8, 0.11634612083435059]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 16, 1947054.5714429845, 1395.368973226431, 543.2508732606709, 137.74785193522524, 40.8, 0.12340164184570312]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 17, 712667.7244524601, 844.1964963516847, 486.79678317048365, 98.40505155340033, 30.05, 0.11877965927124023]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 18, 1825215.5058298602, 1351.0053685422054, 556.2537061841431, 144.50355513124703, 40.27, 0.11492800712585449]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 19, 1819150.724550042, 1348.758957171385, 557.5239576124471, 141.6870290803758, 39.96, 0.11505246162414551]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 20, 1762931.9739080984, 1327.754485553748, 575.2486456608917, 143.98324700171878, 39.42, 0.10462117195129395]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 21, 1745608.1336271446, 1321.2146432836507, 582.586403253598, 144.65911291322462, 39.27, 0.11496186256408691]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 12550, 'epsilon': 0.1, 'gamma': 1e-07, 'kernel': 'rbf'}", 22, 904374.0103374531, 950.9858097455782, 344.82534817222006, 95.20732410752272, 33.31, 0.1184849739074707]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 23, 633875.7800196707, 796.1631616821207, 529.7365531132549, 114.40863993102224, 41.95, 0.11762309074401855]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['c.lynx', "{'C': 1255555, 'epsilon': 0.1, 'gamma': 1e-08, 'kernel': 'rbf'}", 24, 902368.7618181639, 949.9309247614607, 712.1764723102106, 131.6315875249632, 42.96, 0.12838530540466309]
