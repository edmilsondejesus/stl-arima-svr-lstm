# %%
#!pip install seaborn
#!pip install openpyxl
#!pip install sklearn

# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sbs
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.svm import SVR
from matplotlib import pyplot
import time
import csv
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

# %%
file_data = 'SN_m_tot_V2.0.csv'
path_name='../datasets/'
path_name_results='../results/'
file_result = 'Result_SVR_sunspot.csv'

# %%
dataset = pd.read_csv(f'{path_name}{file_data}', sep =';', encoding = 'latin1', decimal='.')
dataset.columns = ['year','month', 'date','total_sunspot_number','std_derivation','num_observations','def_prov_indicator']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3295 entries, 0 to 3294
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  3295 non-null   int64
#  1   month                 3295 non-null   int64
#  2   date                  3295 non-null   float64
#  3   total_sunspot_number  3295 non-null   float64
#  4   std_derivation        3295 non-null   float64
#  5   num_observations      3295 non-null   int64
#  6   def_prov_indicator    3295 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 180.3 KB

# %%
#verifica se existe variáveis nulas 
dataset.isna().sum()
# Out:
# year                    0
# month                   0
# date                    0
# total_sunspot_number    0
# std_derivation          0
# num_observations        0
# def_prov_indicator      0
# dtype: int64

# %%
def salvar_resultado(nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration):
  #Script to write training cycle results
  data = [nm_dataset, ds_best_param, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duration]
  fields = ['Dataset','Best Params','n_time_steps','MSE','RMSE','MAE','MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "a",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(data)  
  print(fields)
  print(data)
    
#Script to create the results file
def criar_arquivo_resultado():
  fields = ['Dataset','Best Params','n_time_steps','MSE','RMSE','MAE','MAPE','sMAPE','Duration']
  with open(f'{path_name_results}{file_result}', "w",newline='') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(fields)

# %%
def previsao_SVR(nm_dataset, dataset, n_time_steps):
    
    # Handle n_time_steps = 0 (no lag features)
    if n_time_steps == 0:
        # Create a constant feature for the model to work
        df = pd.DataFrame()
        df['num_observations'] = dataset['num_observations']
        df['constant'] = 1  # dummy feature
        df.dropna(inplace=True)
        
        # Split dataset into train (80%) and test (20%)
        nlinhas = int(np.round(df.shape[0] * 0.80))
        
        max_size_train_split = int(np.round(nlinhas / 5))
        max_size_test_split = int(np.round((df.shape[0] - nlinhas) / 5))
        size_split = 5
        
        # Prepare training data
        X_train = df.iloc[0:nlinhas, 1:2]  # constant column only
        y_train = df.iloc[0:nlinhas, 0].values
        
        # Prepare test data
        X_test = df.iloc[nlinhas:dataset.shape[0], 1:2]
        y_test = df.iloc[nlinhas:dataset.shape[0], 0].values
        
    else:
        # Original code for n_time_steps > 0
        # Dataframe treatment
        df = pd.DataFrame()
        df['num_observations'] = dataset['num_observations']
        
        # Time series transform - create lag features
        for n_step in range(1, n_time_steps + 1, 1):
            df['vl-' + str(n_step)] = dataset['num_observations'].shift(n_step)
        
        df.dropna(inplace=True)
        
        # Split dataset into train (80%) and test (20%)
        nlinhas = int(np.round(df.shape[0] * 0.80))
        
        max_size_train_split = int(np.round(nlinhas / 5))
        max_size_test_split = int(np.round((df.shape[0] - nlinhas) / 5))
        size_split = 5
        
        # Prepare training data
        X_train = df.iloc[0:nlinhas, 1:1 + n_time_steps]
        y_train = df.iloc[0:nlinhas, 0].values
        
        # Prepare test data
        X_test = df.iloc[nlinhas:dataset.shape[0], 1:1 + n_time_steps]
        y_test = df.iloc[nlinhas:dataset.shape[0], 0].values
    
    # Apply StandardScale
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()
    
    # Scale features
    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    
    # Scale target
    y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).ravel()
    
    # Store training execution start time
    Hora_Inicio = time.time()
    
    # Time series cross-validation
    ts_cv = TimeSeriesSplit(
        n_splits=size_split,
        max_train_size=max_size_train_split,
        gap=2,
        test_size=max_size_test_split,
    )
    
    # Hyperparameters for SVR
    C = [12550, 125550, 1255555]
    gamma = [0.00001, 0.000001, 0.0000001, 0.00000001]
    epsilon = [0.1, 0.01, 0.001, 0.0001]
    
    hyper_params = [{'kernel': ['rbf'], 'C': C, 'gamma': gamma, 'epsilon': epsilon}]
    
    # Create SVR model
    modelo = SVR(max_iter=3000)
    
    # Grid search with cross-validation using scaled data
    grid = GridSearchCV(
        modelo,
        param_grid=hyper_params,
        verbose=20,
        n_jobs=-4,
        cv=ts_cv,
        scoring='neg_mean_absolute_percentage_error'
    )
    
    # Train on scaled data
    grid.fit(X_train_scaled, y_train_scaled)
    
    resultado = str(grid.best_params_)
    
    # Predict on scaled test data
    predict_scaled = grid.predict(X_test_scaled)
    
    # Inverse transform predictions to original scale
    predict = scaler_y.inverse_transform(predict_scaled.reshape(-1, 1)).ravel()
    
    # Store training execution end time
    Hora_Fim = time.time()
    
    # Calculate training execution duration
    Duracao = Hora_Fim - Hora_Inicio
    
    # Calculate metrics with original scale values
    # Mean Squared Error
    MSE = mean_squared_error(y_test, predict)
    
    # Root Mean Squared Error
    RMSE = np.sqrt(mean_squared_error(y_test, predict))
    
    # Mean Absolute Error
    MAE = median_absolute_error(y_pred=predict, y_true=y_test)
    
    # Mean Absolute Percentage Error (with protection against division by zero)
    MAPE = ((np.mean(np.abs(y_test - predict) / (y_test + 1e-10)))) * 100
    
    # Symmetric Mean Absolute Percentage Error (with protection against division by zero)
    sMAPE = round(
        np.mean(
            np.abs(predict - y_test) /
            ((np.abs(predict) + np.abs(y_test)) + 1e-10)
        ) * 100, 2
    )
    
    # Save results
    salvar_resultado(nm_dataset, resultado, n_time_steps, MSE, RMSE, MAE, MAPE, sMAPE, Duracao)

# %%
#create file to results
criar_arquivo_resultado()

print('forecast for new sunspot number')
for n_time_steps in range(0,25): #predict with 0 to 24 past values of medition
    grid = previsao_SVR('sunspot', dataset, n_time_steps)
# Out:
# forecast for new sunspot number
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.0001, 'gamma': 1e-05, 'kernel': 'rbf'}", 0, 339193.0564356461, 582.4028300374631, 488.0014278146191, 74.0078716584455, 70.01, 3.690577507019043]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.0001, 'gamma': 1e-05, 'kernel': 'rbf'}", 1, 6877.389329156978, 82.93002670418585, 30.342005646791904, 8.688594071611618, 4.46, 0.8202567100524902]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.0001, 'gamma': 1e-05, 'kernel': 'rbf'}", 2, 17673.957749949324, 132.94343816055505, 50.30591827261219, 12.02645204625108, 6.65, 0.8107502460479736]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 3, 72528.65295385546, 269.31144230027706, 121.52428382202996, 24.877536170852643, 15.28, 0.8481729030609131]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.0001, 'gamma': 1e-05, 'kernel': 'rbf'}", 4, 43726.44641934089, 209.1086952265278, 70.12628901986525, 16.83220246267754, 9.84, 0.9096541404724121]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-06, 'kernel': 'rbf'}", 5, 8645.371068545257, 92.98048756887252, 43.20539634462831, 10.331326142387603, 5.19, 0.9424219131469727]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-06, 'kernel': 'rbf'}", 6, 10697.350330110388, 103.42799587205772, 38.8710519495699, 11.680368159805155, 5.58, 1.0039253234863281]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-06, 'kernel': 'rbf'}", 7, 8308.01868646503, 91.14833342670084, 40.02953540959868, 9.945202946506686, 5.04, 0.9353604316711426]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-06, 'kernel': 'rbf'}", 8, 7777.813939597034, 88.19191538682576, 37.671216853634405, 9.329270681417205, 4.76, 0.9913380146026611]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 9, 131815.65962675164, 363.0642637698616, 177.4550470497809, 33.185798840275574, 22.55, 1.0165858268737793]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 10, 143611.16057302922, 378.9606319567103, 188.65627564671507, 35.09411935218409, 24.3, 0.9910917282104492]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 11, 22437.85285712757, 149.79269961225603, 36.46903829913208, 11.942171130106361, 6.49, 0.9596166610717773]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 12, 240151.55439713784, 490.05260370406955, 277.7575483442547, 48.95938869475408, 37.3, 0.9572970867156982]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 13, 108942.33528480372, 330.0641381380348, 146.729784624475, 28.789150195058404, 18.85, 0.8547241687774658]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 14, 197805.34363277987, 444.75312661383265, 246.55955489620058, 43.43361298830109, 32.05, 0.9441211223602295]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 15, 152746.89374599393, 390.8284710022978, 203.38324536413512, 36.69960701438684, 25.59, 0.9802062511444092]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 16, 161658.98689004348, 402.0683858375879, 200.32989378826113, 36.8816882631057, 26.09, 0.9519608020782471]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 17, 395988.50110993936, 629.2761723678558, 455.41061482521695, 72.6983676509796, 62.04, 1.0355322360992432]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 18, 92856.73413106252, 304.7240294611873, 139.98603046364315, 27.94664823314164, 17.77, 1.086416244506836]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 19, 273199.9631191633, 522.6853385347281, 330.28110313961554, 54.04795924741946, 42.53, 1.018017053604126]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 20, 35572.642975323986, 188.6071127378922, 31.740373166213203, 11.566626051434737, 6.59, 1.0720090866088867]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 21, 56952.87883359899, 238.64802289899447, 40.90290155733703, 14.794101307368054, 8.97, 1.1499979496002197]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 22, 188225.2392513555, 433.8493278217168, 252.45975438265583, 43.4944902838133, 31.74, 1.0859780311584473]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 23, 250061.60050484352, 500.0615967106888, 294.5278401761164, 50.379370141861244, 38.91, 1.159813642501831]
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# ['Dataset', 'Best Params', 'n_time_steps', 'MSE', 'RMSE', 'MAE', 'MAPE', 'sMAPE', 'Duration']
# ['sunspot', "{'C': 12550, 'epsilon': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}", 24, 111761.89159061921, 334.3080788593348, 138.39541849206654, 28.063176247024185, 18.42, 1.1648688316345215]
# c:\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=3000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
